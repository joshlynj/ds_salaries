# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ds_df = pd.read_csv('../data/ds_salaries.csv')

# %%
ds_df.shape
# Out:
# (3755, 11)

# %%
ds_df.T
# Out:
#                                         0            1            2     \
# work_year                               2023         2023         2023
# experience_level                          SE           MI           MI
# employment_type                           FT           CT           CT
# job_title           Principal Data Scientist  ML Engineer  ML Engineer
# salary                                 80000        30000        25500
# salary_currency                          EUR          USD          USD
# salary_in_usd                          85847        30000        25500
# employee_residence                        ES           US           US
# remote_ratio                             100          100          100
# company_location                          ES           US           US
# company_size                               L            S            S
#
#                               3               4                  5     \
# work_year                     2023            2023               2023
# experience_level                SE              SE                 SE
# employment_type                 FT              FT                 FT
# job_title           Data Scientist  Data Scientist  Applied Scientist
# salary                      175000          120000             222200
# salary_currency                USD             USD                USD
# salary_in_usd               175000          120000             222200
# employee_residence              CA              CA                 US
# remote_ratio                   100             100                  0
# company_location                CA              CA                 US
# company_size                     M               M                  L
#
#                                  6               7               8     \
# work_year                        2023            2023            2023
# experience_level                   SE              SE              SE
# employment_type                    FT              FT              FT
# job_title           Applied Scientist  Data Scientist  Data Scientist
# salary                         136000          219000          141000
# salary_currency                   USD             USD             USD
# salary_in_usd                  136000          219000          141000
# employee_residence                 US              CA              CA
# remote_ratio                        0               0               0
# company_location                   US              CA              CA
# company_size                        L               M               M
#
#                               9     ...                      3745  \
# work_year                     2023  ...                      2021
# experience_level                SE  ...                        SE
# employment_type                 FT  ...                        FT
# job_title           Data Scientist  ...  Director of Data Science
# salary                      147100  ...                    168000
# salary_currency                USD  ...                       USD
# salary_in_usd               147100  ...                    168000
# employee_residence              US  ...                        JP
# remote_ratio                     0  ...                         0
# company_location                US  ...                        JP
# company_size                     M  ...                         S
#
#                               3746                                3747  \
# work_year                     2021                                2021
# experience_level                MI                                  MI
# employment_type                 FT                                  FT
# job_title           Data Scientist  Applied Machine Learning Scientist
# salary                      160000                              423000
# salary_currency                SGD                                 USD
# salary_in_usd               119059                              423000
# employee_residence              SG                                  US
# remote_ratio                   100                                  50
# company_location                IL                                  US
# company_size                     M                                   L
#
#                              3748             3749            3750  \
# work_year                    2021             2021            2020
# experience_level               MI               SE              SE
# employment_type                FT               FT              FT
# job_title           Data Engineer  Data Specialist  Data Scientist
# salary                      24000           165000          412000
# salary_currency               EUR              USD             USD
# salary_in_usd               28369           165000          412000
# employee_residence             MT               US              US
# remote_ratio                   50              100             100
# company_location               MT               US              US
# company_size                    L                L               L
#
#                                         3751            3752  \
# work_year                               2021            2020
# experience_level                          MI              EN
# employment_type                           FT              FT
# job_title           Principal Data Scientist  Data Scientist
# salary                                151000          105000
# salary_currency                          USD             USD
# salary_in_usd                         151000          105000
# employee_residence                        US              US
# remote_ratio                             100             100
# company_location                          US              US
# company_size                               L               S
#
#                                      3753                  3754
# work_year                            2020                  2021
# experience_level                       EN                    SE
# employment_type                        CT                    FT
# job_title           Business Data Analyst  Data Science Manager
# salary                             100000               7000000
# salary_currency                       USD                   INR
# salary_in_usd                      100000                 94665
# employee_residence                     US                    IN
# remote_ratio                          100                    50
# company_location                       US                    IN
# company_size                            L                     L
#
# [11 rows x 3755 columns]

# %%
ds_df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
for col in ds_df:
    print(ds_df['job_title'].unique())
# Out:
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
#  'Data Infrastructure Engineer' 'Software Data Engineer' 'AI Programmer'
#  'Data Operations Engineer' 'BI Developer' 'Data Science Lead'
#  'Deep Learning Researcher' 'BI Analyst' 'Data Science Consultant'
#  'Data Analytics Specialist' 'Machine Learning Infrastructure Engineer'
#  'BI Data Analyst' 'Head of Data Science' 'Insight Analyst'
#  'Deep Learning Engineer' 'Machine Learning Software Engineer'
#  'Big Data Architect' 'Product Data Analyst'
#  'Computer Vision Software Engineer' 'Azure Data Engineer'
#  'Marketing Data Engineer' 'Data Analytics Lead' 'Data Lead'
#  'Data Science Engineer' 'Machine Learning Research Engineer'
#  'NLP Engineer' 'Manager Data Management' 'Machine Learning Developer'
#  '3D Computer Vision Researcher' 'Principal Machine Learning Engineer'
#  'Data Analytics Engineer' 'Data Analytics Consultant'
#  'Data Management Specialist' 'Data Science Tech Lead'
#  'Data Scientist Lead' 'Cloud Data Engineer' 'Data Operations Analyst'
#  'Marketing Data Analyst' 'Power BI Developer' 'Product Data Scientist'
#  'Principal Data Architect' 'Machine Learning Manager'
#  'Lead Machine Learning Engineer' 'ETL Developer' 'Cloud Data Architect'
#  'Lead Data Engineer' 'Head of Machine Learning' 'Principal Data Analyst'
#  'Principal Data Engineer' 'Staff Data Scientist' 'Finance Data Analyst']

# %%
for col in ds_df:
    print(ds_df['experience_level'].unique())
# Out:
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']

# %%
for col in ds_df:
    print(ds_df['employment_type'].unique())
# Out:
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']

# %%
for col in ds_df:
    print(ds_df['salary_currency'].unique())
# Out:
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']

# %%
for col in ds_df:
    print(ds_df['employee_residence'].unique())
# Out:
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']

# %%
for col in ds_df:
    print(ds_df['company_location'].unique())
# Out:
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']

# %%
for col in ds_df:
    print(ds_df['company_size'].unique())
# Out:
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']

# %%
# highest_pay = ds_df.groupby("job_title")["salary_in_usd"].max().sort_values(ascending=False)
# highest_pay_top = highest_pay.head(10).sort_values(ascending=False).to_frame()
# highest_pay_top


highest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=False)
#lowest_pay_top = lowest_pay.head(10).sort_values(ascending=False).to_frame()
mask = highest_pay['company_location'].isin(["US"]) & highest_pay['employment_type'].isin(["FT"])
highest_pay_top = highest_pay[mask].head(10)
highest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_17216\3346542170.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   highest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=False)
#                                      salary_in_usd employment_type  \
# job_title
# Data Science Tech Lead                      375000              FT
# Cloud Data Architect                        250000              FT
# Data Lead                                   200000              FT
# Principal Machine Learning Engineer         190000              FT
# Principal Data Engineer                     185000              FT
# Data Infrastructure Engineer                143000              FT
# Business Intelligence Engineer              129300              FT
# Manager Data Management                     125000              FT
# MLOps Engineer                              124000              FT
# Cloud Database Engineer                     115000              FT
#
#                                     company_location
# job_title
# Data Science Tech Lead                            US
# Cloud Data Architect                              US
# Data Lead                                         US
# Principal Machine Learning Engineer               US
# Principal Data Engineer                           US
# Data Infrastructure Engineer                      US
# Business Intelligence Engineer                    US
# Manager Data Management                           US
# MLOps Engineer                                    US
# Cloud Database Engineer                           US

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = highest_pay_top.index, x = highest_pay_top.salary_in_usd, orient="h", palette="crest")
# ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)')
plt.ylabel('Job Title')
plt.title('The 10 Highest Paid Data Science Jobs In The U.S. (2022-2023)')
# Out:
# Text(0.5, 1.0, 'The 10 Highest Paid Data Science Jobs In The U.S. (2022-2023)')

# %%
lowest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#lowest_pay_top = lowest_pay.head(10).sort_values(ascending=False).to_frame()
mask = lowest_pay['company_location'].isin(["US"]) & lowest_pay['employment_type'].isin(["FT"])
#lowest_pay_top = lowest_pay[mask].head(10).sort_values(by = 'salary_in_usd', ascending=False)
lowest_pay_top = lowest_pay[mask].head(10)
lowest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_17216\1413609776.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lowest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#                            salary_in_usd employment_type company_location
# job_title
# BI Data Engineer                   60000              FT               US
# Data Operations Engineer           60000              FT               US
# Data Operations Analyst            66000              FT               US
# Data Specialist                    70000              FT               US
# Applied Scientist                  72000              FT               US
# Financial Data Analyst             75000              FT               US
# Data Analytics Specialist          85000              FT               US
# Data Modeler                       90700              FT               US
# BI Developer                      100000              FT               US
# Cloud Database Engineer           115000              FT               US

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = lowest_pay_top.index, x = lowest_pay_top.salary_in_usd, orient="h", palette="crest")
#ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)')
plt.ylabel('Job Title')
plt.title('The 10 Lowest Paid Data Science Jobs (2022-2023)')
# Out:
# Text(0.5, 1.0, 'The 10 Lowest Paid Data Science Jobs (2022-2023)')

# %%
ds_df
ft_only_df = ds_df.drop(ds_df[ds_df['employment_type'] != "FT"].index)
us_ft_df = ft_only_df.drop(ft_only_df[ft_only_df['company_location'] !="US"].index)
us_ft_df
# Out:
#       work_year experience_level employment_type  \
# 5          2023               SE              FT
# 6          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# 9                         Data Scientist  147100             USD
# 10                        Data Scientist   90700             USD
# 11                          Data Analyst  130000             USD
# ...                                  ...     ...             ...
# 3747  Applied Machine Learning Scientist  423000             USD
# 3749                     Data Specialist  165000             USD
# 3750                      Data Scientist  412000             USD
# 3751            Principal Data Scientist  151000             USD
# 3752                      Data Scientist  105000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 5            222200                 US             0               US
# 6            136000                 US             0               US
# 9            147100                 US             0               US
# 10            90700                 US             0               US
# 11           130000                 US           100               US
# ...             ...                ...           ...              ...
# 3747         423000                 US            50               US
# 3749         165000                 US           100               US
# 3750         412000                 US           100               US
# 3751         151000                 US           100               US
# 3752         105000                 US           100               US
#
#      company_size
# 5               L
# 6               L
# 9               M
# 10              M
# 11              M
# ...           ...
# 3747            L
# 3749            L
# 3750            L
# 3751            L
# 3752            S
#
# [3022 rows x 11 columns]

# %%
us_ft_df['job_count'] = us_ft_df.groupby('job_title')['job_title'].transform('count')
us_ft_df
# Out:
#       work_year experience_level employment_type  \
# 5          2023               SE              FT
# 6          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# 9                         Data Scientist  147100             USD
# 10                        Data Scientist   90700             USD
# 11                          Data Analyst  130000             USD
# ...                                  ...     ...             ...
# 3747  Applied Machine Learning Scientist  423000             USD
# 3749                     Data Specialist  165000             USD
# 3750                      Data Scientist  412000             USD
# 3751            Principal Data Scientist  151000             USD
# 3752                      Data Scientist  105000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 5            222200                 US             0               US
# 6            136000                 US             0               US
# 9            147100                 US             0               US
# 10            90700                 US             0               US
# 11           130000                 US           100               US
# ...             ...                ...           ...              ...
# 3747         423000                 US            50               US
# 3749         165000                 US           100               US
# 3750         412000                 US           100               US
# 3751         151000                 US           100               US
# 3752         105000                 US           100               US
#
#      company_size  job_count
# 5               L         58
# 6               L         58
# 9               M        673
# 10              M        673
# 11              M        521
# ...           ...        ...
# 3747            L          8
# 3749            L         14
# 3750            L        673
# 3751            L          3
# 3752            S        673
#
# [3022 rows x 12 columns]

# %%
n = 10
most_common = us_ft_df['job_title'].value_counts().head(10).to_frame()
# most_common = ds_df["job_title"].mode()
display(most_common)
# Out:
#                            job_title
# Data Engineer                    906
# Data Scientist                   673
# Data Analyst                     521
# Machine Learning Engineer        219
# Data Architect                    97
# Analytics Engineer                92
# Applied Scientist                 58
# Research Scientist                58
# Data Science Manager              52
# Research Engineer                 31

# %%
most_common_df = us_ft_df.groupby("job_count", as_index=False)[["salary_in_usd", "job_title"]].mean(numeric_only=True).sort_values(by = 'job_count', ascending=False).head(10)


index_labels = ["Data Engineer", 
         "Data Scientist", 
         "Data Analyst", 
         "Machine Learning Engineer", 
         "Data Architect",
         "Analytics Engineer", 
         "Applied Scientist", 
         "Research Scientist", 
         "Data Science Manager", 
         "Research Engineer"]

most_common_df.index = index_labels
display(most_common_df)
# Out:
#                            job_count  salary_in_usd
# Data Engineer                    906  152944.600442
# Data Scientist                   673  158370.478455
# Data Analyst                     521  117024.905950
# Machine Learning Engineer        219  174385.127854
# Data Architect                    97  163092.690722
# Analytics Engineer                92  159024.347826
# Applied Scientist                 58  184705.344828
# Research Scientist                52  199379.576923
# Data Science Manager              31  168156.580645
# Research Engineer                 25  180417.160000

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(x = most_common_df.index, y = most_common_df.salary_in_usd, palette="crest")
ax2=ax1.twinx()
sns.lineplot(data = most_common_df['job_count'], marker='o', sort = False, ax=ax2, color = '#aa42f5')
ax1.set_ylabel('Salary (in USD)')
ax2.set_ylabel('Job Count', color = '#aa42f5')
ax1.set_xlabel('Job Title')
ax1.tick_params(axis='x', rotation=45)
plt.title('The 10 Most Common Job Titles and Their Average Pay (2022-2023)')
# Out:
# Text(0.5, 1.0, 'The 10 Most Common Job Titles and Their Average Pay (2022-2023)')

# %%
work_year_df = us_ft_df['work_year'].value_counts()
work_year_df
# Out:
# 2023    1568
# 2022    1331
# 2021      94
# 2020      29
# Name: work_year, dtype: int64

# %%
exp_df = us_ft_df['experience_level'].value_counts()
exp_df
# Out:
# SE    2259
# MI     491
# EN     175
# EX      97
# Name: experience_level, dtype: int64

# %%
remote_df = us_ft_df[['remote_ratio',"company_size"]].sort_values(by='company_size', ascending=False)
#type(remote_df)
remote_df
# Out:
#       remote_ratio company_size
# 3752           100            S
# 3421           100            S
# 3547           100            S
# 3534           100            S
# 3533           100            S
# ...            ...          ...
# 3123           100            L
# 3122             0            L
# 3121             0            L
# 3118           100            L
# 5                0            L
#
# [3022 rows x 2 columns]

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.lineplot(y = remote_df['remote_ratio'], x = remote_df['company_size'], marker='o', sort = False, color = '#aa42f5')
ax1
#sns.load_dataset("remote").pivot("")
# Out:
# <Axes: xlabel='company_size', ylabel='remote_ratio'>

# %%
columns_to_analyze = ['company_size', 'remote_ratio']

# Compute the correlation matrix
corr_matrix = signals[columns_to_analyze].corr()

# Iterate over the correlation matrix and print the correlated categories
for col1 in corr_matrix.columns:
    for col2 in corr_matrix.columns:
        if col1 != col2:
            correlation = corr_matrix.loc[col1, col2]
            if correlation >= 0.5 or correlation <= -0.5:
                print(f"Correlation between {col1} and {col2}: {correlation}")
