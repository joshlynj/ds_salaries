# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ds_df = pd.read_csv('../data/ds_salaries.csv')

# %%
ds_dupe = ds_df[ds_df.duplicated()]

# %%
ds_dupe
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# 3441       2022               SE              FT       Data Engineer  115000
# 3586       2021               MI              FT       Data Engineer  200000
# 3709       2021               MI              FT      Data Scientist   76760
#
# ...

# %%
ds_df.shape
# Out:
# (3755, 11)

# %%
ds_df.T
# Out:
#                                         0            1            2     \
# work_year                               2023         2023         2023
# experience_level                          SE           MI           MI
# employment_type                           FT           CT           CT
# job_title           Principal Data Scientist  ML Engineer  ML Engineer
# salary                                 80000        30000        25500
# salary_currency                          EUR          USD          USD
# salary_in_usd                          85847        30000        25500
# employee_residence                        ES           US           US
# remote_ratio                             100          100          100
# company_location                          ES           US           US
# company_size                               L            S            S
#
#                               3               4                  5     \
# ...

# %%
ds_df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
for col in ds_df:
    print(ds_df['job_title'].unique())
# Out:
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
# ...

# %%
for col in ds_df:
    print(ds_df['experience_level'].unique())
# Out:
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']
# ['SE' 'MI' 'EN' 'EX']

# %%
for col in ds_df:
    print(ds_df['employment_type'].unique())
# Out:
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']
# ['FT' 'CT' 'FL' 'PT']

# %%
for col in ds_df:
    print(ds_df['salary_currency'].unique())
# Out:
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
#  'PLN' 'HUF' 'CZK' 'DKK' 'JPY' 'MXN' 'TRY' 'CLP']
# ['EUR' 'USD' 'INR' 'HKD' 'CHF' 'GBP' 'AUD' 'SGD' 'CAD' 'ILS' 'BRL' 'THB'
# ...

# %%
for col in ds_df:
    print(ds_df['employee_residence'].unique())
# Out:
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
#  'HR' 'PL' 'KW' 'VN' 'CY' 'AR' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK'
#  'IT' 'MA' 'LT' 'BE' 'AS' 'IR' 'HU' 'SK' 'CN' 'CZ' 'CR' 'TR' 'CL' 'PR'
#  'DK' 'BO' 'PH' 'DO' 'EG' 'ID' 'AE' 'MY' 'JP' 'EE' 'HN' 'TN' 'RU' 'DZ'
#  'IQ' 'BG' 'JE' 'RS' 'NZ' 'MD' 'LU' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'PT' 'NL' 'CH' 'CF' 'FR' 'AU'
#  'FI' 'UA' 'IE' 'IL' 'GH' 'AT' 'CO' 'SG' 'SE' 'SI' 'MX' 'UZ' 'BR' 'TH'
# ...

# %%
for col in ds_df:
    print(ds_df['company_location'].unique())
# Out:
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
# ...

# %%
for col in ds_df:
    print(ds_df['company_size'].unique())
# Out:
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']
# ['L' 'S' 'M']

# %%
ds_df[ds_df['salary_in_usd'] == 5679]
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3667       2021               MI              FT  Data Scientist  420000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3667             INR           5679                 IN           100
#
#      company_location company_size
# 3667               US            S

# %%
# highest_pay = ds_df.groupby("job_title")["salary_in_usd"].max().sort_values(ascending=False)
# highest_pay_top = highest_pay.head(10).sort_values(ascending=False).to_frame()
# highest_pay_top


highest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=False)
#lowest_pay_top = lowest_pay.head(10).sort_values(ascending=False).to_frame()
mask = highest_pay['company_location'].isin(["US"]) & highest_pay['employment_type'].isin(["FT"])
highest_pay_top = highest_pay[mask].head(10)
highest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_3804\3346542170.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   highest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=False)
#                                      salary_in_usd employment_type  \
# job_title
# Data Science Tech Lead                      375000              FT
# Cloud Data Architect                        250000              FT
# Data Lead                                   200000              FT
# Principal Machine Learning Engineer         190000              FT
# Principal Data Engineer                     185000              FT
# Data Infrastructure Engineer                143000              FT
# Business Intelligence Engineer              129300              FT
# Manager Data Management                     125000              FT
# ...

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = highest_pay_top.index, x = highest_pay_top.salary_in_usd, orient="h", palette="crest")
# ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)', size = 15)
plt.ylabel('Job Title', size = 15)
plt.title('The 10 Highest Paid Data Science Jobs (2020-2023)', size =18)
# Out:
# Text(0.5, 1.0, 'The 10 Highest Paid Data Science Jobs (2020-2023)')

# %%
lowest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#lowest_pay_top = lowest_pay.head(10).sort_values(ascending=False).to_frame()
mask = lowest_pay['company_location'].isin(["US"]) & lowest_pay['employment_type'].isin(["FT"])
#lowest_pay_top = lowest_pay[mask].head(10).sort_values(by = 'salary_in_usd', ascending=False)
lowest_pay_top = lowest_pay[mask].head(10)
lowest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_3804\1413609776.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lowest_pay = ds_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#                            salary_in_usd employment_type company_location
# job_title
# BI Data Engineer                   60000              FT               US
# Data Operations Engineer           60000              FT               US
# Data Operations Analyst            66000              FT               US
# Data Specialist                    70000              FT               US
# Applied Scientist                  72000              FT               US
# Financial Data Analyst             75000              FT               US
# Data Analytics Specialist          85000              FT               US
# ...

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = lowest_pay_top.index, x = lowest_pay_top.salary_in_usd, orient="h", palette="crest")
#ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)',size =15)
plt.ylabel('Job Title',size =15)
plt.title('The 10 Lowest Paid Data Science Jobs (2020-2023)',size =18)
# Out:
# Text(0.5, 1.0, 'The 10 Lowest Paid Data Science Jobs (2020-2023)')

# %%
ds_df['company_location'].value_counts()
# Out:
# US    3040
# GB     172
# CA      87
# ES      77
# IN      58
#       ...
# MK       1
# BS       1
# IR       1
# CR       1
# MT       1
# Name: company_location, Length: 72, dtype: int64

# %%
ds_df['employment_type'].value_counts()
# Out:
# FT    3718
# PT      17
# CT      10
# FL      10
# Name: employment_type, dtype: int64

# %%
ds_df
ft_only_df = ds_df.drop(ds_df[ds_df['employment_type'] != "FT"].index)
us_ft_df = ft_only_df.drop(ft_only_df[ft_only_df['company_location'] !="US"].index)
us_ft_res_df = us_ft_df.drop(us_ft_df[us_ft_df['employee_residence'] !="US"].index)
us_ft_res_df
# Out:
#       work_year experience_level employment_type  \
# 5          2023               SE              FT
# 6          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# 9                         Data Scientist  147100             USD
# 10                        Data Scientist   90700             USD
# ...

# %%
highest_pay = us_ft_res_df.groupby("job_title")["salary_in_usd", "employment_type", "employee_residence", "company_location"].max().sort_values(by = 'salary_in_usd', ascending=False)
highest_pay_top = highest_pay.head(10)
highest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_3804\1770450817.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   highest_pay = us_ft_res_df.groupby("job_title")["salary_in_usd", "employment_type", "employee_residence", "company_location"].max().sort_values(by = 'salary_in_usd', ascending=False)
#                                     salary_in_usd employment_type  \
# job_title
# Research Scientist                         450000              FT
# Applied Machine Learning Scientist         423000              FT
# Data Scientist                             412000              FT
# Data Analytics Lead                        405000              FT
# Data Analyst                               385000              FT
# Applied Data Scientist                     380000              FT
# Data Architect                             376080              FT
# ...

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = highest_pay_top.index, x = highest_pay_top.salary_in_usd, orient="h", palette="crest")
# ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)', size = 15)
plt.ylabel('Job Title', size = 15)
plt.title('The 10 Highest Paid Data Science Jobs (2020-2023)', size =18)
# Out:
# Text(0.5, 1.0, 'The 10 Highest Paid Data Science Jobs (2020-2023)')

# %%
lowest_pay = us_ft_res_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#lowest_pay_top = lowest_pay.head(10).sort_values(ascending=False).to_frame()
# mask = lowest_pay['company_location'].isin(["US"]) & lowest_pay['employment_type'].isin(["FT"])
#lowest_pay_top = lowest_pay[mask].head(10).sort_values(by = 'salary_in_usd', ascending=False)
lowest_pay_top = lowest_pay.head(10)
lowest_pay_top
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_3804\2316580943.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   lowest_pay = us_ft_res_df.groupby("job_title")["salary_in_usd", "employment_type", "company_location"].min().sort_values(by = 'salary_in_usd', ascending=True)
#                           salary_in_usd employment_type company_location
# job_title
# Data Engineer                     24000              FT               US
# Data Scientist                    38000              FT               US
# Data Manager                      45600              FT               US
# Data Analyst                      46000              FT               US
# Business Data Analyst             48000              FT               US
# AI Scientist                      50000              FT               US
# Analytics Engineer                54000              FT               US
# ...

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(y = lowest_pay_top.index, x = lowest_pay_top.salary_in_usd, orient="h", palette="crest")
#ax.set_xlim(100000, 460000)
plt.xlabel('Salary (in USD)',size =15)
plt.ylabel('Job Title',size =15)
plt.title('The 10 Lowest Paid Data Science Jobs (2020-2023)',size =18)
# Out:
# Text(0.5, 1.0, 'The 10 Lowest Paid Data Science Jobs (2020-2023)')

# %%
us_ft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3022 entries, 5 to 3752
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3022 non-null   int64
#  1   experience_level    3022 non-null   object
#  2   employment_type     3022 non-null   object
#  3   job_title           3022 non-null   object
#  4   salary              3022 non-null   int64
#  5   salary_currency     3022 non-null   object
#  6   salary_in_usd       3022 non-null   int64
#  7   employee_residence  3022 non-null   object
#  8   remote_ratio        3022 non-null   int64
#  9   company_location    3022 non-null   object
#  10  company_size        3022 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 347.9+ KB

# %%
us_ft_df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3022.000000  3.022000e+03    3022.000000   3022.000000
# mean   2022.468564  1.580928e+05  152214.251820     44.159497
# std       0.607390  2.207245e+05   55413.403295     49.339950
# min    2020.000000  2.000000e+04    5679.000000      0.000000
# 25%    2022.000000  1.150000e+05  115000.000000      0.000000
# 50%    2023.000000  1.450000e+05  145000.000000      0.000000
# 75%    2023.000000  1.850000e+05  185000.000000    100.000000
# max    2023.000000  1.100000e+07  450000.000000    100.000000

# %%
ds_dupe = us_ft_df[ds_df.duplicated()]
ds_dupe
# Out:
# C:\Users\joshy\AppData\Local\Temp\ipykernel_3804\227470294.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ds_dupe = us_ft_df[ds_df.duplicated()]
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3417       2022               SE              FT       Data Engineer   80000
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# ...

# %%
dupe_dropped = us_ft_df.drop_duplicates()
dupe_dropped
# Out:
#       work_year experience_level employment_type  \
# 5          2023               SE              FT
# 6          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# 9                         Data Scientist  147100             USD
# 10                        Data Scientist   90700             USD
# ...

# %%
us_ft_res_df['job_count'] = us_ft_res_df.groupby('job_title')['job_title'].transform('count')
us_ft_res_df
# Out:
#       work_year experience_level employment_type  \
# 5          2023               SE              FT
# 6          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# 9                         Data Scientist  147100             USD
# 10                        Data Scientist   90700             USD
# ...

# %%
n = 10
most_common = us_ft_res_df['job_title'].value_counts().head(10).to_frame()
# most_common = ds_df["job_title"].mode()
display(most_common)
# Out:
#                            job_title
# Data Engineer                    903
# Data Scientist                   666
# Data Analyst                     516
# Machine Learning Engineer        218
# Data Architect                    97
# Analytics Engineer                91
# Applied Scientist                 58
# Research Scientist                57
# Data Science Manager              51
# Research Engineer                 31

# %%
most_common_df = us_ft_res_df.groupby("job_count", as_index=False)[["salary_in_usd", "job_title"]].mean(numeric_only=True).sort_values(by = 'job_count', ascending=False).head(10)


index_labels = ["Data Engineer", 
         "Data Scientist", 
         "Data Analyst", 
         "Machine Learning Engineer", 
         "Data Architect",
         "Analytics Engineer", 
         "Applied Scientist", 
         "Research Scientist", 
         "Data Science Manager", 
         "Research Engineer"]

most_common_df.index = index_labels
display(most_common_df)
# Out:
#                            job_count  salary_in_usd
# Data Engineer                    903  153065.341085
# Data Scientist                   666  159510.015015
# Data Analyst                     516  117616.232558
# Machine Learning Engineer        218  174496.986239
# Data Architect                    97  163092.690722
# Analytics Engineer                91  160244.395604
# Applied Scientist                 58  190264.482759
# Research Scientist                57  181411.929825
# Data Science Manager              51  202228.313725
# Research Engineer                 31  168156.580645

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
sns.barplot(x = most_common_df.index, y = most_common_df.salary_in_usd, palette="crest")
ax2=ax1.twinx()
sns.lineplot(data = most_common_df['job_count'], marker='o', sort = False, ax=ax2, color = '#aa42f5')
ax1.set_ylabel('Salary (in USD)',size =15)
ax2.set_ylabel('Job Count', size=15, color = '#aa42f5')
ax1.set_xlabel('Job Title', size =15)
ax1.tick_params(axis='x', rotation=45)
plt.title('The 10 Most Common Jobs and Their Average Pay (2020-2023)',size =18)
# Out:
# Text(0.5, 1.0, 'The 10 Most Common Jobs and Their Average Pay (2020-2023)')

# %%
work_year_df = us_ft_res_df['work_year'].value_counts()
work_year_df
# Out:
# 2023    1563
# 2022    1320
# 2021      83
# 2020      25
# Name: work_year, dtype: int64

# %%
exp_df = us_ft_res_df['experience_level'].value_counts()
exp_df
# Out:
# SE    2248
# MI     478
# EN     169
# EX      96
# Name: experience_level, dtype: int64

# %%
remote_df = us_ft_res_df[['remote_ratio',"company_size"]].sort_values(by='company_size', ascending=False)
#type(remote_df)
remote_df
# Out:
#       remote_ratio company_size
# 3752           100            S
# 901              0            S
# 3520           100            S
# 3511            50            S
# 3495            50            S
# ...            ...          ...
# 702              0            L
# 2569           100            L
# 2564             0            L
# 3314           100            L
# 5                0            L
#
# [2991 rows x 2 columns]

# %%
grouped = remote_df.groupby(['company_size', 'remote_ratio']).size().unstack()

grouped.plot(kind='bar', stacked=True)
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.title('Remote Ratios by Company Size')
plt.legend(title='Remote Ratio', loc='upper right')
plt.show()

# %%
s_df = remote_df[remote_df['company_size'] == 'S']
m_df = remote_df[remote_df['company_size'] == 'M']
l_df = remote_df[remote_df['company_size'] == 'L']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))

sns.countplot(x='remote_ratio', data=s_df, ax=axes[0], palette="crest")
axes[0].set_title('Small Company', fontsize=15)
axes[0].set_xlabel('Remote Ratio', fontsize=15)
axes[0].set_ylabel('Jobs Total', fontsize=15)

sns.countplot(x='remote_ratio', data=m_df, ax=axes[1], palette="crest")
axes[1].set_title('Medium Company', fontsize=15)
axes[1].set_xlabel('Remote Ratio', fontsize=15)
axes[1].set_ylabel('Jobs Total', fontsize=15)

sns.countplot(x='remote_ratio', data=l_df, ax=axes[2], palette="crest")
axes[2].set_title('Large Company', fontsize=15)
axes[2].set_xlabel('Remote Ratio', fontsize=15)
axes[2].set_ylabel('Jobs Total', fontsize=15)

plt.suptitle('Remote Ratios by Company Size 2020-2023', fontsize=18)

plt.tight_layout()

# %%
#fig, ax1 = plt.subplots(figsize=(16,9))
#sns.lineplot(y = remote_df['remote_ratio'], x = remote_df['company_size'], marker='o', sort = False, color = '#aa42f5')
#ax1
#sns.load_dataset("remote").pivot("")
#sns.scatterplot(data=remote_df, x="company_size", y="remote_ratio", hue="company_size")
#remote_df.plot(kind='hexbin', y = remote_df['company_size'], x=remote_df['remote_ratio'])

# %%
pivot = remote_df.pivot_table(index='company_size', columns='remote_ratio', aggfunc='size')

sns.heatmap(pivot, annot=True, fmt='d', cmap='YlGnBu')
plt.xlabel('Remote Ratio')
plt.ylabel('Company Size')
plt.title('Remote Ratios by Company Size')
plt.show()

# %%
exp_df = us_ft_res_df[['experience_level',"salary_in_usd", "job_title"]].sort_values(by='salary_in_usd', ascending=False)
display(exp_df)
# Out:
#      experience_level  salary_in_usd                           job_title
# 3522               MI         450000                  Research Scientist
# 3747               MI         423000  Applied Machine Learning Scientist
# 3750               SE         412000                      Data Scientist
# 3463               SE         405000                 Data Analytics Lead
# 1288               SE         385000                        Data Analyst
# ...               ...            ...                                 ...
# 2591               SE          38000                      Data Scientist
# 2595               SE          38000                      Data Scientist
# 3387               SE          25000                       Data Engineer
# 3042               MI          24000                       Data Engineer
# 3043               MI          24000                       Data Engineer
#
# [2991 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
order = ['EN', 'MI', 'SE', 'EX']
index_labels = ["Entry", "Intermediate", "Senior", "Exectuve"]

sns.boxplot(x='experience_level', y='salary_in_usd', data=exp_df, order= order, ax=ax, palette="crest")

ax.set_xlabel('Experience Level', fontsize=15)
ax.set_ylabel('Salary (in USD)', fontsize=15)
ax.set_title('Salary Distribution by Experience Level (2020-2023)', size =18)
# Out:
# Text(0.5, 1.0, 'Salary Distribution by Experience Level (2020-2023)')

# %%
def filter_outliers(df,column,std_threshold = 3):
    mean = df[column].mean()
    std = df[column].std()
    std_threshold = 3
    df_filtered = df[(np.abs(df[column] - mean) <= std_threshold * std)]
    return df_filtered
